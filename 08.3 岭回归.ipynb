# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 岭回归默认使用的是SAG

# %% [markdown]
# ***

# %% [markdown]
# 正则化的线性回归：from sklean.linear_model import LinearRegression
# 随机梯度下降的线性回归：from sklean.linear_model import SGDRegressor
# 岭回归：from sklean.linear_model import Ridge

# %% [markdown]
# ***

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
# 1.数据集划分
boston = load_boston()
x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target, random_state=2, test_size=0.3)

# %%
# 2.标准化
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)

# %%
# 3.模型训练
estimator = Ridge(alpha=0.8, max_iter=5000)
estimator.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.8, copy_X=True, fit_intercept=True, max_iter=5000,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# 4.训练后的模型参数
print(estimator.coef_)
print('-'*60)
print(estimator.intercept_)
# Out:
# [-0.81320106  0.6624468  -0.14602931  0.80742123 -1.70736757  2.52488394
#   0.50818767 -2.66575542  2.69353635 -1.77257165 -2.25253952  1.16151264
#  -4.22886876]
# ------------------------------------------------------------
# 22.572881355932246

# %%
# 5.模型评估
y_prediction = estimator.predict(x_test)
mean_squared_error(y_test, y_prediction)
# Out:
# 23.013958066025626

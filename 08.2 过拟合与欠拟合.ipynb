# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 将w的和加到损失函数中，在保证损失最小的过程中，让w的值也尽可能小，w越小，越不容易过拟合（用极限的思想来理解，当w为0时，多项式更简单）
# L1正则化是将后面的w平方改为w的绝对值

# %% [markdown]
# 加上L1正则化的叫LASSO回归
# 加上L2正则化的叫岭回归
